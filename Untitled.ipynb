# %%
import lux
from vega_datasets import data

# %%
df = data.cars()

# %%
_ = df.Origin
_ = df.describe()
df.history
# Out:
# [
# <Event (id: 140510400007808) @[3]: col_ref, cols=['Origin']> with weight 0.475,
# <Event (id: 140509202021488) @[3]: describe, cols=['Miles_per_Gallon', 'Cylinders', 'Displacement', 'Horsepower', 'Weight_in_lbs', 'Acceleration']> with weight 1.0
# ]

# %%
df._history.to_JSON()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-112a61c10b5d> in <module>
# ----> 1 df._history.to_JSON()
#
# AttributeError: 'History' object has no attribute 'to_JSON'

# %%
df
# Out:
# /Users/wepperso/opt/anaconda3/envs/lux_workspace/lib/python3.9/site-packages/IPython/core/formatters.py:918: UserWarning:
# Unexpected error in rendering Lux widget and recommendations. Falling back to Pandas display.
# Please report the following issue on Github: https://github.com/lux-org/lux/issues
#
# /Users/wepperso/opt/anaconda3/envs/lux_workspace/lib/python3.9/site-packages/lux/core/frame.py:712: UserWarning:Traceback (most recent call last):
#   File "/Users/wepperso/opt/anaconda3/envs/lux_workspace/lib/python3.9/site-packages/lux/core/frame.py", line 674, in _ipython_display_
#     self.maintain_recs()
#   File "/Users/wepperso/opt/anaconda3/envs/lux_workspace/lib/python3.9/site-packages/lux/core/frame.py", line 528, in maintain_recs
#     self._widget = rec_df.render_widget()
#   File "/Users/wepperso/opt/anaconda3/envs/lux_workspace/lib/python3.9/site-packages/lux/core/frame.py", line 762, in render_widget
#     return luxwidget.LuxWidget( # widget
# ...
